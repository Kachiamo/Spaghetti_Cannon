# %%
import pandas as pd
from pathlib import Path
from signals import VelocityTradingStrategy
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
ticker = "TSLA"

# %%
df = pd.read_csv(
    Path(f"../Resources/{ticker}.csv"), 
    index_col="Date",
    parse_dates=True,
)

# Review the DataFrame
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-12-20  21.803333  22.019333  20.791332  21.025333  21.025333  136078500
# 2018-12-21  21.160000  21.564667  20.829332  21.318001  21.318001  120252000
# 2018-12-24  20.900000  20.966667  19.680000  19.692667  19.692667   83398500
# 2018-12-26  20.000000  21.798000  19.606001  21.739332  21.739332  122446500
# 2018-12-27  21.322666  21.478001  20.100000  21.075333  21.075333  128626500

# %%
strategy = VelocityTradingStrategy(df, ticker=ticker)
strategy.df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2018-12-20  21.803333  22.019333  20.791332  21.025333  21.025333  136078500
# 2018-12-21  21.160000  21.564667  20.829332  21.318001  21.318001  120252000
# 2018-12-24  20.900000  20.966667  19.680000  19.692667  19.692667   83398500
# 2018-12-26  20.000000  21.798000  19.606001  21.739332  21.739332  122446500
# 2018-12-27  21.322666  21.478001  20.100000  21.075333  21.075333  128626500
#
#             derivative  Velocity_Signal  Velocity_Action
# Date
# 2018-12-20         NaN                0                0
# 2018-12-21         NaN                0                0
# 2018-12-24         NaN                0                0
# 2018-12-26         NaN                0                0
# 2018-12-27         NaN                0                0

# %%
strategy.plot()
# Out:
# :Overlay
#    .Curve.I          :Curve   [Date]   (Close)
#    .Scatter.Close.I  :Scatter   [Date]   (Close)
#    .Scatter.Close.II :Scatter   [Date]   (Close)
